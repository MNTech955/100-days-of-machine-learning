# %% [markdown]
# <a href="https://colab.research.google.com/github/MNTech955/100-days-of-machine-learning/blob/main/fetching_data_from_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
temp_df
# Out:
#          id                                          title  \
# 0       278                       The Shawshank Redemption
# 1       238                                  The Godfather
# 2       240                          The Godfather Part II
# 3       424                               Schindler's List
# 4       389                                   12 Angry Men
# 5       129                                  Spirited Away
# 6       155                                The Dark Knight
# 7     19404                    Dilwale Dulhania Le Jayenge
# 8       497                                 The Green Mile
# 9       122  The Lord of the Rings: The Return of the King
# 10   496243                                       Parasite
# 11  1181678                          ¿Quieres ser mi hijo?
# 12      680                                   Pulp Fiction
# 13   372058                                     Your Name.
# 14   157336                                   Interstellar
# ...

# %%
#Empty DataFrame banaya
#hink of df like an empty Excel sheet
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#This loop will run from page 1 to page 428
#
for i in range(1,429):
  #This line sends a request to the movie API.
  #So every loop mein new page ka data aayega.
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    #JSON data ko DataFrame mein convert karna
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555  294793        All the Old Knives
# 8556   12500            American Ninja
# 8557   10900              Surveillance
# 8558  531503               Point Blank
# 8559  454699            Monster Family
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
#now we have to convert data to csv
df.to_csv('movies.csv')
